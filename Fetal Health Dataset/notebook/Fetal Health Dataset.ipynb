# %% [markdown]
# # Exploratory Data Analysis on Fetal Health Data

# %% [markdown]
# Import libraries

# %%
#importing the packages will using for this project
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import pickle
# %matplotlib inline

pd.set_option('display.max_columns',300)
plt.style.use('seaborn')
sns.set(rc={'figure.facecolor':'cornflowerblue'})

# %% [markdown]
# Read data

# %%
#reading the csv file
df=pd.read_csv('C:\\Users\\rakhi\\OneDrive\\Desktop\\Fetal Health Dataset\\data\\Fetal_Health.csv')
df_copy=df
df_copy.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %% [markdown]
# Information about the data

# %%
#getting information of DataFrame
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %%
#shape of the dataset
df_copy.shape
# Out:
# (2126, 22)

# %% [markdown]
# Describe data

# %%
df_copy.describe(include='all')
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %%
#renaming column name to make easier to work with
df_copy=df_copy.rename(columns={'baseline value':'baseline_value','prolongued_decelerations':'prolonged_decelerations'})
df_copy.columns
# Out:
# Index(['baseline_value', 'accelerations', 'fetal_movement',
#        'uterine_contractions', 'light_decelerations', 'severe_decelerations',
#        'prolonged_decelerations', 'abnormal_short_term_variability',
#        'mean_value_of_short_term_variability',
#        'percentage_of_time_with_abnormal_long_term_variability',
#        'mean_value_of_long_term_variability', 'histogram_width',
#        'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
#        'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
#        'histogram_median', 'histogram_variance', 'histogram_tendency',
#        'fetal_health'],
#       dtype='object')

# %% [markdown]
# missing data, if there are some missing data that we have to fixed it

# %%
#checking null values
df_copy.isnull().sum()
# Out:
# baseline_value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolonged_decelerations                                   0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %% [markdown]
# There are no null values in the dataset.

# %%
#checking the numerical variables
num_var = [i for i in df_copy.columns if df_copy[i].dtypes != 'string']
print(num_var)
# Out:
# ['baseline_value', 'accelerations', 'fetal_movement', 'uterine_contractions', 'light_decelerations', 'severe_decelerations', 'prolonged_decelerations', 'abnormal_short_term_variability', 'mean_value_of_short_term_variability', 'percentage_of_time_with_abnormal_long_term_variability', 'mean_value_of_long_term_variability', 'histogram_width', 'histogram_min', 'histogram_max', 'histogram_number_of_peaks', 'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean', 'histogram_median', 'histogram_variance', 'histogram_tendency', 'fetal_health']

# %%
df_copy[df_copy.duplicated()] #denoting the duplicate rows
#check if there is any duplicates in the dataset.
# Out:
#       baseline_value  accelerations  fetal_movement  uterine_contractions  \
# 68             140.0          0.007           0.000                 0.004
# 234            123.0          0.000           0.000                 0.000
# 306            145.0          0.000           0.020                 0.000
# 324            135.0          0.000           0.000                 0.000
# 333            144.0          0.000           0.019                 0.000
# 787            123.0          0.003           0.003                 0.000
# 791            123.0          0.003           0.004                 0.000
# 798            146.0          0.000           0.000                 0.003
# 849            138.0          0.002           0.000                 0.004
# 1113           122.0          0.000           0.000                 0.000
# 1114           122.0          0.000           0.000                 0.000
# 1115           122.0          0.000           0.000                 0.000
# ...

# %% [markdown]
# There are some duplicates in the dataset

# %%
#dropping duplicates
df_copy = df.drop_duplicates(subset = None , keep = 'first', inplace = False)
df_copy
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %% [markdown]
# after dropping the duplicates we have 2113 rows and 22 features.

# %%
#checking the outliers in the dataframe
plt.figure(figsize=(25,5))
sns.boxplot(data=df_copy)
# Out:
# <AxesSubplot:>

# %%
#checking the outliers in the dataframe
plt.figure(figsize=(25,5))
sns.boxplot(data=df_copy)
# Out:
# <AxesSubplot:>

# %%
#To more understand data we will find correlation between fetal health and other features.
df_copy.corr()
# Out:
#                                                     baseline value  \
# baseline value                                            1.000000
# accelerations                                            -0.081885
# fetal_movement                                           -0.033949
# uterine_contractions                                     -0.149587
# light_decelerations                                      -0.159836
# severe_decelerations                                     -0.053706
# prolongued_decelerations                                 -0.105003
# abnormal_short_term_variability                           0.303502
# mean_value_of_short_term_variability                     -0.278344
# percentage_of_time_with_abnormal_long_term_vari...        0.283918
# mean_value_of_long_term_variability                      -0.028901
# histogram_width                                          -0.147150
# histogram_min                                             0.360129
# ...

# %%
#generate heatmap to display correlations in data
plt.figure(figsize=(15,10))
sns.heatmap(df_copy.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
target = df_copy["fetal_health"]
corr = df_copy.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    fig, axes = plt.subplots(figsize=(15, 15))
    ax = sns.heatmap(corr,mask=mask,square=True,linewidths=2.5,cmap="viridis",annot=True)

# %% [markdown]
# There is strong correlation between baseline value and histogram mode , histogram median and histogram mean. Histogram number of peaks and histogram width is also having good correlation.

# %%
#Univariate Analysis
#Checking skewness
df_copy.skew()
# Out:
# baseline value                                             0.019760
# accelerations                                              1.200207
# fetal_movement                                             7.788014
# uterine_contractions                                       0.154295
# light_decelerations                                        1.709470
# severe_decelerations                                      17.299865
# prolongued_decelerations                                   4.308787
# abnormal_short_term_variability                           -0.011863
# mean_value_of_short_term_variability                       1.656144
# percentage_of_time_with_abnormal_long_term_variability     2.206038
# mean_value_of_long_term_variability                        1.343133
# histogram_width                                            0.311019
# histogram_min                                              0.117185
# histogram_max                                              0.575534
# ...

# %%
#sns.pairplot(df_copy)

# %%
#checking the values of target variable
df_copy['fetal_health'].value_counts()
# Out:
# 1.0    1646
# 2.0     292
# 3.0     175
# Name: fetal_health, dtype: int64

# %%
df_copy.fetal_health.describe()
# Out:
# count    2113.000000
# mean        1.303833
# std         0.614279
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: fetal_health, dtype: float64

# %%
#df_copy.fetal_health.hist()
sns.countplot(data=df_copy, x='fetal_health')
plt.title('numbber of samples')
# Out:
# Text(0.5, 1.0, 'numbber of samples')

# %%
df_copy.groupby(by='fetal_health').mean()
# Out:
#               baseline value  accelerations  fetal_movement  \
# fetal_health
# 1.0               131.998177       0.004002        0.008002
# 2.0               141.650685       0.000277        0.008284
# 3.0               131.668571       0.000394        0.025823
#
#               uterine_contractions  light_decelerations  severe_decelerations  \
# fetal_health
# 1.0                       0.004801             0.001952          6.075334e-07
# 2.0                       0.002404             0.000541          0.000000e+00
# 3.0                       0.003806             0.003691          3.428571e-05
#
#               prolongued_decelerations  abnormal_short_term_variability  \
# fetal_health
# 1.0                           0.000052                        42.501823
# 2.0                           0.000096                        61.791096
# 3.0                           0.001280                        64.554286
#
#               mean_value_of_short_term_variability  \
# fetal_health
# ...

# %%
#check the data tyes to do encoding
df_copy.dtypes
# Out:
# baseline value                                            float64
# accelerations                                             float64
# fetal_movement                                            float64
# uterine_contractions                                      float64
# light_decelerations                                       float64
# severe_decelerations                                      float64
# prolongued_decelerations                                  float64
# abnormal_short_term_variability                           float64
# mean_value_of_short_term_variability                      float64
# percentage_of_time_with_abnormal_long_term_variability    float64
# mean_value_of_long_term_variability                       float64
# histogram_width                                           float64
# histogram_min                                             float64
# histogram_max                                             float64
# ...

# %%
#independent var and target var
df_features=df_copy.iloc[:,:-1]
df_labels=df_copy.iloc[:,-1]

# %%
#detect the outliers
for i,j in enumerate(df_features.columns):
    q1=df_features[j].quantile(0.25)
    q3=df_features[j].quantile(0.75)
    iqr=q3-q1
    u=q3+1.5*iqr
    l=q1-1.5*iqr

    print('upper_limit',df_features[df_features[j]>u].count()[j])
    print('lower_limit',df_features[df_features[j]<l].count()[j])
# Out:
# upper_limit 0
# lower_limit 0
# upper_limit 14
# lower_limit 0
# upper_limit 305
# lower_limit 0
# upper_limit 1
# lower_limit 0
# upper_limit 150
# lower_limit 0
# upper_limit 7
# lower_limit 0
# upper_limit 178
# lower_limit 0
# upper_limit 0
# lower_limit 0
# upper_limit 70
# lower_limit 0
# upper_limit 305
# lower_limit 0
# upper_limit 71
# lower_limit 0
# upper_limit 0
# lower_limit 0
# upper_limit 0
# lower_limit 0
# upper_limit 24
# lower_limit 0
# upper_limit 19
# lower_limit 0
# upper_limit 502
# lower_limit 0
# upper_limit 12
# lower_limit 61
# upper_limit 3
# lower_limit 42
# upper_limit 5
# lower_limit 23
# upper_limit 184
# lower_limit 0
# upper_limit 0
# lower_limit 0

# %%
#identifying the data distribution and outliers in our dataset
for i,j in enumerate(df_features.columns):
    plt.subplot(1,2,1)
    sns.distplot(df_copy[j])#hue='fetal_health')
    plt.subplot(1,2,2)
    sns.boxplot(x=df_copy[j],data=df_copy)
    plt.show()

# %% [markdown]
# # Saving the cleaned data in pickle file

# %%
import pickle
with open('C:\\Users\\rakhi\\OneDrive\\Desktop\\Fetal Health Dataset\\models\\ExplorataryDataAnalysis.pkl', 'wb') as f:
    pickle.dump(df_copy, f)
